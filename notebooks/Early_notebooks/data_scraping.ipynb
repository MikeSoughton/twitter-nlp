# %% [markdown]
# # Notebook to scrape tweets containing specific keywords
#
# This notebook will ... . Running this notebook requires an internet connection and a twitter developer account.
#
# Note that this must be run locally using the dev version of snscrape as found in environment.yml (running via a local runtime on google colab will not work)
#
# To run jupyter notebook using a particular environment do in the terminal:
#
# <code>conda install -c anaconda ipykernel<code>
# <code>python -m ipykernel install --user --name=env name<code>
#
# Then select the environment from the kernel dropdown menu

# %%
# We don't want to exceed the max limit of bot checks
# So give it here and stop running if it is reached
botometer_max_limit = 2
bot_check_count = 0

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from tqdm import tqdm

# %%
# Just pandas display options
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# /var/folders/hx/0dxb0wn51wx5pscstjkwf2gc000qqf/T/ipykernel_4735/1119663756.py:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# Tweets are collected from 23:59 on the date in question until the number of tweets to download is reached. It is best then to get the same number of tweets each day. Note that there are **A LOT** of tweets about Ukraine now (obviously); about 10 per second even at midnight (in English)! Assuming this rate of tweeting is constant, which it probably isn't, we would have about 864000 tweets per day.

# %%
# A function to create a pair of lists for days to search
def create_date_lists(since_initial, until_final):
    """
    Creates a a pair of lists for since and until dates of the form
    since_list = ['2022-02-24', '2022-02-25', '2022-02-26']
    until_list = ['2022-02-25', '2022-02-26', '2022-02-27']
    """
    import datetime

    diff = datetime.datetime.strptime(until_final, "%Y-%m-%d") - datetime.datetime.strptime(since_initial, "%Y-%m-%d")
    diff = diff.days

    since_initial_datetime = datetime.datetime.strptime(since_initial, "%Y-%m-%d")
    until_initial_datetime = since_initial_datetime + datetime.timedelta(days=1)
    until_initial_datetime = datetime.datetime.strftime(until_initial_datetime, "%Y-%m-%d")

    diff = datetime.datetime.strptime(until_final, "%Y-%m-%d") - datetime.datetime.strptime(since_initial, "%Y-%m-%d")
    diff = diff.days

    since_list = []
    until_list = []
    for day in range(diff):
        since_plus_day = since_initial_datetime + datetime.timedelta(days=day)
        since_plus_day = datetime.datetime.strftime(since_plus_day, "%Y-%m-%d")
        since_list.append(since_plus_day)

        until_plus_day = since_initial_datetime + datetime.timedelta(days=day+1)
        until_plus_day = datetime.datetime.strftime(until_plus_day, "%Y-%m-%d")
        until_list.append(until_plus_day)
        
    return since_list, until_list

# %% [markdown]
# Now we can download tweets and put them into a dataframe. We can download tweets in English, Russian and Ukrainian, here for 'ukraine', 'украина' (Ukraine in Russian) or 'україни' (Ukraine in Ukrainian).

# %%
# Each word seperated by a space is treated as a unique keyword here
keywords_en = 'mcdonalds russia' 
keywords_ru = 'макдональдс россия'
keywords_uk = 'макдональдс росія'

# We can get a number of tweets from each day 
num_tweets = 5000 # Per day
start_date = '2022-02-24'
end_date = '2022-03-17'

# Use our function to get a pair of lists for each day
since_list, until_list = create_date_lists(start_date, end_date)

def scrape_tweets_by_keywords(keyword, lang, since_list, until_list):
    # Loop through each since and until date in the since and until lists, create a dataframe for each day and stitch them together
    tweets_lang_df = pd.DataFrame(columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])
    for day, (since,until) in enumerate(list(zip(since_list, until_list))):
        print("Day:", day)
        tweets_list = []
        for i,tweet in enumerate(tqdm(sntwitter.TwitterSearchScraper(keyword + ' since:' + since + ' until:' + until + ' lang:' + lang).get_items())):
            if i > num_tweets:
                break
            tweets_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])

        # Creating a dataframe from the tweets list above
        tweets_lang_day_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])
        
        # Stitch the daily dataframes together
        tweets_lang_df = pd.concat([tweets_lang_df, tweets_lang_day_df])
        tweets_lang_df.reset_index(drop=True, inplace=True)
        
    return tweets_lang_df 


tweets_en_df = scrape_tweets_by_keywords(keywords_en, 'en', since_list, until_list)
tweets_ru_df = scrape_tweets_by_keywords(keywords_ru, 'ru', since_list, until_list)
tweets_uk_df = scrape_tweets_by_keywords(keywords_uk, 'uk', since_list, until_list)
tweets_en_df.head(1000)
# Out:
# Day: 0
# 90it [00:29,  3.08it/s]
# Day: 1
# 101it [01:23,  1.21it/s]
#                      Datetime             Tweet Id  \
# 0   2022-03-27 23:58:44+00:00  1508232082388144135
# 1   2022-03-27 23:56:17+00:00  1508231465384906755
# 2   2022-03-27 23:51:44+00:00  1508230319505346563
# 3   2022-03-27 22:56:40+00:00  1508216461332037636
# 4   2022-03-27 22:49:59+00:00  1508214779193737219
# 5   2022-03-27 22:29:14+00:00  1508209556530282505
# 6   2022-03-27 21:37:12+00:00  1508196461959426049
# 7   2022-03-27 21:36:51+00:00  1508196375133102089
# 8   2022-03-27 21:27:17+00:00  1508193968835682305
# 9   2022-03-27 21:24:38+00:00  1508193299458412549
# 10  2022-03-27 21:23:20+00:00  1508192975398273026
# 11  2022-03-27 21:14:10+00:00  1508190668329521153
# 12  2022-03-27 20:41:18+00:00  1508182394418995200
# 13  2022-03-27 20:32:50+00:00  1508180267151863825
# 14  2022-03-27 20:31:33+00:00  1508179943053799435
# 15  2022-03-27 20:20:51+00:00  1508177247449980932
# 16  2022-03-27 20:12:39+00:00  1508175186671112197
# 17  2022-03-27 20:04:18+00:00  1508173084783693831
# 18  2022-03-27 20:01:56+00:00  1508172487414190080
# 19  2022-03-27 19:57:50+00:00  1508171455405740033
# 20  2022-03-27 19:53:04+00:00  1508170258942771201
# 21  2022-03-27 19:47:37+00:00  1508168886297972740
# 22  2022-03-27 19:43:13+00:00  1508167778624315407
# 23  2022-03-27 19:09:51+00:00  1508159383179603970
# 24  2022-03-27 18:54:07+00:00  1508155424062820352
# 25  2022-03-27 18:42:27+00:00  1508152488234348545
# 26  2022-03-27 18:32:55+00:00  1508150087880425473
# 27  2022-03-27 18:24:50+00:00  1508148053525643273
# 28  2022-03-27 18:09:47+00:00  1508144265167532032
# 29  2022-03-27 17:35:33+00:00  1508135648368242690
# 30  2022-03-27 17:34:01+00:00  1508135265361010692
# 31  2022-03-27 17:33:59+00:00  1508135255047389186
# 32  2022-03-27 17:32:38+00:00  1508134917015805962
# 33  2022-03-27 17:30:15+00:00  1508134318367027205
# 34  2022-03-27 17:17:45+00:00  1508131172127330312
# 35  2022-03-27 17:13:11+00:00  1508130022904770567
# 36  2022-03-27 17:12:53+00:00  1508129947658952718
# 37  2022-03-27 16:59:14+00:00  1508126512096366594
# 38  2022-03-27 16:57:25+00:00  1508126052647899137
# 39  2022-03-27 16:41:34+00:00  1508122064875569154
# 40  2022-03-27 16:39:04+00:00  1508121436963196934
# 41  2022-03-27 16:25:58+00:00  1508118137979428869
# 42  2022-03-27 16:23:37+00:00  1508117547916398594
# 43  2022-03-27 16:13:22+00:00  1508114968998289409
# 44  2022-03-27 16:07:39+00:00  1508113528091152389
# 45  2022-03-27 15:53:40+00:00  1508110012295561218
# 46  2022-03-27 15:40:23+00:00  1508106666188943361
# 47  2022-03-27 15:34:33+00:00  1508105199734476802
# 48  2022-03-27 15:29:22+00:00  1508103894706139146
# 49  2022-03-27 15:21:46+00:00  1508101980551585798
# 50  2022-03-27 15:12:56+00:00  1508099758455328770
# 51  2022-03-27 15:04:04+00:00  1508097526905413634
# 52  2022-03-27 14:55:32+00:00  1508095380780691460
# 53  2022-03-27 14:30:53+00:00  1508089178420043778
# 54  2022-03-27 14:26:33+00:00  1508088085132816384
# 55  2022-03-27 14:25:37+00:00  1508087852286062598
# 56  2022-03-27 14:23:45+00:00  1508087384210092041
# 57  2022-03-27 13:59:36+00:00  1508081302821642241
# 58  2022-03-27 13:27:37+00:00  1508073255944478724
# 59  2022-03-27 13:22:15+00:00  1508071905445691397
# 60  2022-03-27 13:11:45+00:00  1508069263990472709
# 61  2022-03-27 12:33:07+00:00  1508059540771651585
# 62  2022-03-27 11:56:21+00:00  1508050285817704453
# 63  2022-03-27 11:24:27+00:00  1508042259425550343
# 64  2022-03-27 10:15:15+00:00  1508024846273609730
# 65  2022-03-27 10:08:32+00:00  1508023154563817473
# 66  2022-03-27 10:00:40+00:00  1508021175032549378
# 67  2022-03-27 09:49:04+00:00  1508018254748430342
# 68  2022-03-27 09:47:56+00:00  1508017971704254467
# 69  2022-03-27 09:28:00+00:00  1508012955480244224
# 70  2022-03-27 09:07:50+00:00  1508007877813882880
# 71  2022-03-27 08:57:08+00:00  1508005184857063431
# 72  2022-03-27 08:51:04+00:00  1508003659514318851
# 73  2022-03-27 08:43:27+00:00  1508001742490935297
# 74  2022-03-27 08:23:50+00:00  1507996804863959042
# 75  2022-03-27 07:55:37+00:00  1507989703273889792
# 76  2022-03-27 07:34:17+00:00  1507984336234156035
# 77  2022-03-27 07:30:46+00:00  1507983449906298884
# 78  2022-03-27 07:03:04+00:00  1507976480327753728
# 79  2022-03-27 06:01:02+00:00  1507960867647762434
# 80  2022-03-27 05:48:54+00:00  1507957817940000772
# 81  2022-03-27 05:37:01+00:00  1507954826193551367
# 82  2022-03-27 05:30:22+00:00  1507953153425096704
# 83  2022-03-27 05:01:27+00:00  1507945874302849033
# 84  2022-03-27 04:24:52+00:00  1507936669755867136
# 85  2022-03-27 02:42:07+00:00  1507910808436711426
# 86  2022-03-27 01:19:59+00:00  1507890143008415746
# 87  2022-03-27 01:05:25+00:00  1507886476419293191
# 88  2022-03-27 00:29:35+00:00  1507877458690727948
# 89  2022-03-27 00:00:25+00:00  1507870115945082884
# 90  2022-03-28 23:49:09+00:00  1508592055622139904
# 91  2022-03-28 23:47:37+00:00  1508591670190821378
# 92  2022-03-28 23:46:01+00:00  1508591270184296453
# 93  2022-03-28 23:45:37+00:00  1508591168942407680
# 94  2022-03-28 23:45:24+00:00  1508591114420248580
# 95  2022-03-28 23:44:48+00:00  1508590962821705728
# 96  2022-03-28 23:44:37+00:00  1508590916122341376
# 97  2022-03-28 23:39:32+00:00  1508589637329375234
# 98  2022-03-28 23:37:55+00:00  1508589230087413763
# 99  2022-03-28 23:37:12+00:00  1508589050722234368
# 100 2022-03-28 23:36:58+00:00  1508588993155321859
# 101 2022-03-28 23:30:59+00:00  1508587484984139781
# 102 2022-03-28 23:26:30+00:00  1508586358654189571
# 103 2022-03-28 23:25:02+00:00  1508585988263747596
# 104 2022-03-28 23:23:03+00:00  1508585491066593282
# 105 2022-03-28 23:20:13+00:00  1508584775728041988
# 106 2022-03-28 23:19:04+00:00  1508584488816758795
# 107 2022-03-28 23:16:12+00:00  1508583765576060930
# 108 2022-03-28 22:58:40+00:00  1508579355064254467
# 109 2022-03-28 22:54:38+00:00  1508578339325415426
# 110 2022-03-28 22:50:39+00:00  1508577336228208645
# 111 2022-03-28 22:38:29+00:00  1508574273127993345
# 112 2022-03-28 22:35:01+00:00  1508573401346191365
# 113 2022-03-28 22:34:35+00:00  1508573290889158665
# 114 2022-03-28 22:33:51+00:00  1508573108860563458
# 115 2022-03-28 22:16:43+00:00  1508568796428124162
# 116 2022-03-28 22:13:23+00:00  1508567958024593411
# 117 2022-03-28 21:48:21+00:00  1508561657357905931
# 118 2022-03-28 21:44:56+00:00  1508560795776524305
# 119 2022-03-28 21:40:43+00:00  1508559736270049281
# 120 2022-03-28 21:28:25+00:00  1508556639443595268
# 121 2022-03-28 21:08:47+00:00  1508551700017262596
# 122 2022-03-28 21:02:13+00:00  1508550047931240449
# 123 2022-03-28 20:27:36+00:00  1508541336680423424
# 124 2022-03-28 20:20:49+00:00  1508539627837218820
# 125 2022-03-28 20:09:37+00:00  1508536811047378945
# 126 2022-03-28 20:05:11+00:00  1508535693353627648
# 127 2022-03-28 20:04:44+00:00  1508535580614922243
# 128 2022-03-28 19:59:44+00:00  1508534322541776907
# 129 2022-03-28 19:59:08+00:00  1508534171550949381
# 130 2022-03-28 19:56:49+00:00  1508533587104219139
# 131 2022-03-28 19:56:23+00:00  1508533478966632450
# 132 2022-03-28 19:56:17+00:00  1508533456942284804
# 133 2022-03-28 19:55:59+00:00  1508533379456716803
# 134 2022-03-28 19:54:29+00:00  1508533000061001729
# 135 2022-03-28 19:47:04+00:00  1508531134556250119
# 136 2022-03-28 19:46:44+00:00  1508531053123837957
# 137 2022-03-28 19:42:21+00:00  1508529946452541450
# 138 2022-03-28 19:40:08+00:00  1508529391369818113
# 139 2022-03-28 19:18:36+00:00  1508523970613727239
# 140 2022-03-28 19:16:24+00:00  1508523419658248198
# 141 2022-03-28 19:11:27+00:00  1508522172461031428
# 142 2022-03-28 18:50:17+00:00  1508516846198263809
# 143 2022-03-28 18:46:02+00:00  1508515774486487040
# 144 2022-03-28 18:38:11+00:00  1508513800105836552
# 145 2022-03-28 18:37:49+00:00  1508513709039181829
# 146 2022-03-28 18:29:09+00:00  1508511528353341445
# 147 2022-03-28 18:22:16+00:00  1508509793736179719
# 148 2022-03-28 18:16:17+00:00  1508508287234359301
# 149 2022-03-28 17:59:44+00:00  1508504124140228609
# 150 2022-03-28 17:48:42+00:00  1508501348979036166
# 151 2022-03-28 17:46:32+00:00  1508500803648061440
# 152 2022-03-28 17:35:11+00:00  1508497945884336134
# 153 2022-03-28 17:32:29+00:00  1508497266482585600
# 154 2022-03-28 17:31:54+00:00  1508497118260039683
# 155 2022-03-28 17:23:30+00:00  1508495003915632640
# 156 2022-03-28 17:14:43+00:00  1508492794868150275
# 157 2022-03-28 17:09:24+00:00  1508491456696172554
# 158 2022-03-28 17:09:24+00:00  1508491456427741190
# 159 2022-03-28 17:00:33+00:00  1508489230871318543
# 160 2022-03-28 16:59:48+00:00  1508489041586630662
# 161 2022-03-28 16:54:45+00:00  1508487769659686919
# 162 2022-03-28 16:46:52+00:00  1508485784894025730
# 163 2022-03-28 16:46:11+00:00  1508485614404096000
# 164 2022-03-28 16:24:15+00:00  1508480094171537415
# 165 2022-03-28 16:23:34+00:00  1508479921764634625
# 166 2022-03-28 16:23:25+00:00  1508479883940610050
# 167 2022-03-28 16:20:27+00:00  1508479140332191744
# 168 2022-03-28 16:18:33+00:00  1508478662248734724
# 169 2022-03-28 16:16:13+00:00  1508478075087904770
# 170 2022-03-28 16:06:05+00:00  1508475523508236290
# 171 2022-03-28 16:06:04+00:00  1508475517275566082
# 172 2022-03-28 15:48:32+00:00  1508471106633666561
# 173 2022-03-28 15:42:45+00:00  1508469650249584644
# 174 2022-03-28 15:39:42+00:00  1508468885082750978
# 175 2022-03-28 15:38:54+00:00  1508468683106050053
# 176 2022-03-28 15:35:35+00:00  1508467849026699269
# 177 2022-03-28 15:35:09+00:00  1508467738339069964
# 178 2022-03-28 15:33:10+00:00  1508467240651440133
# 179 2022-03-28 15:32:59+00:00  1508467195084685315
# 180 2022-03-28 15:31:08+00:00  1508466725725028358
# 181 2022-03-28 15:17:31+00:00  1508463299733692428
# 182 2022-03-28 15:13:52+00:00  1508462383764758539
# 183 2022-03-28 15:13:51+00:00  1508462379281092609
# 184 2022-03-28 15:02:35+00:00  1508459544174804994
# 185 2022-03-28 14:57:05+00:00  1508458159609950220
# 186 2022-03-28 14:44:36+00:00  1508455018986450952
# 187 2022-03-28 14:42:21+00:00  1508454449588674568
# 188 2022-03-28 14:12:07+00:00  1508446840827662338
# 189 2022-03-28 13:46:15+00:00  1508440334178603016
# 190 2022-03-28 13:18:23+00:00  1508433321537249289
#
#                                                                                                                                                                                                                                                                                                                                                                  Text  \
# 0    Officials from Ukraine &amp; Russia will meet Monday in Istanbul, Turkey for the next round of renewal negotiations peace talk
# 1    The way you talk to USA and EU is a little be undiplomatic. When you ask for a favour you have to talk nicely, because they don’t owe you anything. They did a lot for Ukraine. I am hopeful peace will prevail.
# 2    Problem With Peace Talk With Putin And Russia Arranged By Turkey And Israel Is: Ukraine Does Not Fully Trust Turkey And Israel Because They Are Considered As Putin/Russian Satellites And Puppets Too.
# 3    @mirekziek Donbass love war while Lavrov daughter lives in England. Lavrov doesn't give a damn about Donbass. Putin is scared that Lavrov talk's about peace. There are few crazy nationalist in Ukraïne. In Russia 75%. Putin is afraid Ru people see the truth and kill him.
# 4    @Bobby_314159265 @DoctorFishbones As I see it, Putin isn’t going to pull back if he thinks he’s winning the war but if he sees he’s losing he’s more likely to talk and agree peace, so, yes, supplying Ukraine is the right move.
# 5    @carlbildt they talk of the end of the russian state.  the russian state will be there no matter what, unless they fail to make peace with ukraine and ukraine start pushing into russia.  But  russian imperialistic ambition, that will die should putin fail, as it should.
# 6    @Navsteva You all talk about courage... The Russians are fighting alone against NATO and half the world. Ukraine received 50,000 anti-tank systems and tens of thousands of anti-aircraft missiles, and mercenaries from all over the world and you are talking about the brave Ukrainians? lol
# 7    @RNCResearch You all talk about courage... The Russians are fighting alone against NATO and half the world. Ukraine received 50,000 anti-tank systems and tens of thousands of anti-aircraft missiles, and mercenaries from all over the world and you are talking about the brave Ukrainians? lol
# 8    Ukraine willing to accept neutral status in peace talk with Russia via @nsemgh https://t.co/NRrjEZxT2X #UkraineUnderAttaсk #Ukraine #NATOINUKRAINENOW
# 9    @GerardAraud Dear Sir, I highly value your experience but I beg to differ: we need to continue to talk to Putin, but that does not mean at all that there will be peace in Ukraine. And even if he was replaced by another Putin.
# 10   IF U CHOOSE PEACE TALK DIPLOMATIC WAY &amp; STEP DOWN CAN PROTECT @donetekk @DefenceU @MFA_Ukraine @Ukraine PEOPLES THEN YOU NEED TO CHOOSE THIS BUT YOUR EGO INFLUENCE WITH WESTERN DESTROYED #Ukraine NOTHING ELSE.\n\nYOU @DefenceU NOT CAPABLE TO BATTLE WITH @KremlinRussia THEY WHY?
# 11   From Monday, officials from Russia and Ukraine will start talk for peace in Turkey instead of Belarus.
# 12   @DJMacDonald8 @Reuters Sometimes it is necessary to lose some to gain some. Peace is paramount right now. They can talk of territorial claims later. Ukrainians are dying, their country is being destroyed. The war is not in Russia but Ukraine.
# 13   @mm64852257 @DefenceU @ZelenskyyUa Everyone tried to talk peace with Putin for years.\nMonths leading up to the invasion the US tried.\nUkraine has been in talks with Russia in Poland.\nRussia is not interested in peace.
# 14   Ultimately, since war in Ukraine sparked back up I've been paralyzed with fear about *all* wars + talk of a potential WWIII and confused about the impact my AnCom twitter + irl journalism/activism has on the global superstructure. Taking time to listen + better understand ✌️💖\n7/ https://t.co/3s3vD59Uw2
# 15   It is such a blessing to hear a missionary in Lviv talk weekly about God’s faithfulness and provision in the midst of this ongoing conflict. Pray for Ukraine. Pray for the protection of vulnerable women &amp; children. Pray that the Gospel will spread. Pray for peace.
# 16   @GeoffreytheC @klaverro @anders_aslund Yes. But Russia is not willing to really negotiate right now. They don’t want peace now. There could be serious talks after Russia loses. Ukraine said so many times that it wants to negotiate and talk. Russia has now absurd demands - like to reduce the Ukrainian Army to 1/5.
# 17   @newsmax Please stop the nonsense! Can you talk about diplomacy and peace talk this is disgusting 🤮 how media is playing against the lives of the people of Ukraine 🇺🇦 and Russia 🇷🇺.
# 18   @_james_inman @dethb1rd1960 Russia is "asking for" a neutral Ukraine? They are killing people until they get their way. I see now, all along it's all been about your cowardice anyway."Don't talk back to the big boy, he might hit us too!  Just stay quiet and give him what he wants." And you call me a baby.
# 19   @Jeggit Do not harm captive Russian soldiers as you can exchange them with Ukrainian captive soldiers. It it a war crime to harm the captive soldiers. Be nice to Russian captive soldiers and give them food and let them talk to their family members. Peace will come. #Ukraine #Russia #nato
# 20   @klaverro @anders_aslund Putin wants no peace. He is butchering civilians non-stop, including during so called peace talks. Macron can talk until he drops dead. Putin won’t even notice. The only way to stop the war and Putin is to make sure Ukraine wins. There is no other way t9 make Putin leave Ukraine
# 21   @Ukraine Rather than just talking about victory why don't we talk about peace .... dialogue is better than winning wars..... innocent lives are being lost....have dialogue with Kremlin please..avoid war as much as possible
# 22   @JackPosobiec Neocon Hannity. Tulsi wants to talk about peace. What Hannity is missing is that nuclear weapons won’t be used on Ukraine, they would be used on Western Europe and the U.S. Russia has almost 6000 nukes, and I’m sure some are pointed at us.
# 23   @MacronInEnglish @EmmanuelMacron Mr President our president is strong not like Donald Trump I think you know that so stay on his side he's not escalating he's trying to get Putin's attention and I think that statement got his attention to get out of Ukraine and Russia don't want peace talk he wants land
# 24   @ulrichspeck @EHunterChristie the facts are that this approximately 20 million (or more) population will fight for Ukraine. In guerrilla warfare, etc. There will be no peace. Putin can talk to the Next Lama, and not Macronem, there will be no peace. The politicians will not control it.
# 25   @johan_molen @PronabKumarDas4 @maxseddon I think he or she is saying that Zelenskyy doesn't talk about the threat of NATO expansion or that Ukraine is a destructive puppet government therefore he rejects peace by believing the only resolution is to remove Putin.
# 26   this is first and second let us talk over the dialog of states and what can be result of the Ukraine and russian peace deals and if you want the correct in essential term as the UK and others said for lifting sanctions and other things , let me take it from there
# 27   @FoxNewsSunday @USAmbNATO @PressSec Julianne, like weak Biden is “all talk” in increasing military support for Ukraine &amp; same time find diplomatic solution. There’s zero creativity being exercised by US Admin to find way to give Ukraine more jets, and to help Ukraine Russia peace talks.
# 28   @spriter99880 I'm finding this talk of splitting Ukraine suspicious as it is combined with the chemical weapons talk, and I am thinking the West will launch the false flag chemical weapons attack, then NATO will race in as "peace keepers" to "save" Western Ukraine, thus splitting it.
# 29   @anders_aslund Please do not attempt to insert yourself into the French elections\nTruly, you do not know what you are talking about. Macron's peace talk does not hurt Ukraine
# 30   @anders_aslund No wonder French leaders have a reputation for being surrender-monkeys. Ukraine is beating the Russian invaders. Keep on supporting Ukraine so they keep on driving Russia out.\n\nDon't talk peace with someone who'll never honor it.\nLet Putin beg for peace.\nThen negotiate.
# 31   @anders_aslund The only metric for a lasting peace has to be the internationally recognized Ukraine-Russia border of 1991. Moreover, a full Ukrainian sovereignty over Sevastopol as Putin unilaterally terminated the lease. Anything short of that means perpetual war.
# 32   Talk and walk peace#military equipment to Ukraine in billions of dollars #ex service men from U.K. and other European countries in Ukraine#NATOs hundred thousand armed men on Russian and Ukrainian borders#will only lead to a nuclear war and definitely destruction of Ukraine.
# 33   We pray Russia and Ukraine talk for a peaceful resolution #UkraineRussia  #Peace @kot
# 34   @NewVoiceUkraine Honestly? I think it's useless because putin won't withdraw from Ukraine. But if Ukraine don't talk, russian will claim Ukraine don't want peace. Hard decision to talk while they are killing your citizens. Maybe serve russians some "pasztet" and tea?🇲🇨🇺🇦
# 35   @nexta_tv These negotiations are quite a challenge for Ukraine as it is most tricky to talk to a counterpart with irrational ideas. Even more I admire Ukraine. I trust in Ukraine's ability in convincing the aggressor to give up.
# 36   @KyivIndependent #Ukraine will talk to #Russia... You make peace with your enemies...
# 37   A Talk on Context in the Ukrainian/Russian Conflict with Elina #russia #ukraine #war #peace https://t.co/JmrDjCxzvo
# 38   @debbie_eye @SeanHarcourt @ComicDaveSmith So why he not talk about Haiti? Why he not talk about dead children in Mexico? Why he not talk about dead children in Ukraine? You want me to believe that white comic is worried about Yemen cuz his heart is good? He careful who he for. Very careful pretending.
# 39   PRESIDENT OF UKRAINE ASKS THE WORLD 4 PLANES BOMBS TANKS +MISSILE FIRING GUNS? THOSE ARE HARDLY THE REQUESTS OF A PEACE SEEKING COUNTRY'S LEADER? MORE LIKE SOMEONE ITCHING 2 START WW3? THE WEST MUST IGNORE HIS REQUESTS &amp; TALK 2 RUSSIA WITHOUT HIM?
# 40   @HromadskeUA I keep hearing the talk show question should Ukraine give up Krym in exchange for peace. How?  It is not a rational solution.  there can be no peace if the missiles keep coming from Krym.
# 41   Any action Germany takes short of stopping all purchases of Russian gas and oil is too little, if they're not willing to stop funding Putin's war on Ukraine, all of their talk of peace is meaningless.
# 42   Listen to why @QuincyInst's Marcus Stanley says ending sanctions must be in peace talk negotiations\n\nU.S. Must Support Ukraine-Russia Peace Talks to End the War - https://t.co/FW1kOHaBQA via @Shareaholic
# 43   We've spent weeks reporting on the impact the war in Ukraine has had on business...from the stock market to agriculture. Here we talk to organizers of a recent march for peace held in Des Moines, Iowa. We think you'll find this interesting:  https://t.co/0AUA4n3pEx https://t.co/0w3Dgszyxu
# 44   @montigre @KyivIndependent You’re wrong to think that Putin is or was against the wall. But to give you the benefit of the doubt, he should start by leaving Ukraine for good in its entirety (yes…Crimea), pay for reconstruction, return the people he took from Mariupol to Russia…then we can talk peace
# 45   Only dialogue will end the terror on Ukraine’s innocents. No point saying anything unless it will expedite a ceasefire and peace. Biden’s ‘tough talk’ has no value. https://t.co/ezxSYFUOGw
# 46   @KyivIndependent Well Turkey needs to chat to Russia about those same bridges being burned from the other end. Not anyone else invading a sovereign peace loving country. Only Russia killing innocent people incl kids. We will talk but shit has to happen first. Up to Ukraine anyway, not us.
# 47   @alive_lena @mbk_center No need, because even if these weapons are given to Ukraine Russia will still win Ukrainian in a war. So let talk more about peace
# 48   @KyivIndependent Biden doesn’t want macron to talk to Putin.  Biden doesn’t want peace in Ukraine.  Biden wants European chaos in the headlines instead of Bidens blunders in the USA being front page news.  Biden doesn’t care about how many have died, or will die.  It’s clear by his words.
# 49   @Rodoftruth1 @POTUS I live now in Kyiv (the capital of Ukraine), and I hear 6 sirens of air attacks every day, do you think I don't want peace? But if there are no weapons in Ukraine, Russia will not want to talk to us. Russians are shooting down humanitarian corridors that have been agreed wth them
# 50   @KyivIndependent This war must be stop 🛑 with dialogue and peace \n\nMost of World leaders provoking war not trying to setup peace talk \n\nUS &amp; NATO playing very smart they putting weapon on the shoulder of Ukraine citizens not sending own people ! \n\n@ZelenskyyUa must try peaceful solution
# 51   @AnRajala @KimDotcom @dumbnorwegian85 No. The US created this conflict, funded the rise of NAZIS in Ukraine and own the puppet president who is refusing to talk peace OR agree to Neutrality.\nPretend to be stupid long enough and that’s what you’ll end up.
# 52   Trump would not be 'capable' of holding Ukraine-Russia peace talks, says his former national security adviser John Bolton https://t.co/opST7k9vJf \n\nit would be hard to talk with Trump's lips on Putin's ass.
# 53   Pray for Peace ☮️. Talk for Peace ☮️. Work for Peace. Mr. Putin, tear down this invasion!!! Take your troops back home!! Leave Ukraine!! You can’t win!! Stop the slaughter!!! Peace Train by Cat Stevens   Lyrics https://t.co/sfTNT039xn via @YouTube
# 54   @sc00717 @perennialLA @KyivIndependent yeah, i mean it's not like he's asking for it 💁‍♂️\nand again, depends how he would message his talk. the win for him would be to leave all atrocities happening in ukraine and use leadership language for peace and democracy
# 55   YES. Please RT.\n\nYou know who 'cannot remain in power?’ @DanaBashCNN \n\n@CNN has made a terrible mistake putting her on with a 2-hour edition of State of the Nation.\n\nTalk about inappropriate questions? “What would Ukraine be willing to give up…” to achieve peace w/Putin? https://t.co/HLJ9ODKwcg
# 56   @KyivIndependent My bet is Bidens comments are more constructive than Macron's talks.  \nTalks with the Dictator Putin led to Ukraine agreeing to remove nukes in exchange for Russian commitment to peace.  Putin talk is worthless.
# 57   I believe they're purposely delaying it, cus daddy is the head of the peace talk between Russia and Ukraine https://t.co/siRTElkkhc
# 58   @visegrad24 Ok genocide is better.russia needs to pay for rebuilding Ukraine with there frozen assets before talk of peace.putins economy will go back to the Stone Age if left in power no $ no food hunted by the world Court for genocide.putin threatens nuke war with the world makes hima thug
# 59   @CliffordDMay Stop that crazy talk. The UN is the only thing standing between peace and a war breaking out in the Ukraine.
# 60   @DefenceU Ukraine come to table with Russia. All the oligarch assets be given to Ukraine . When you come to peace talk you speak same language , you are brothers don’t let external influence escalate this war .. enough deaths no more 🙏🏽🌞
# 61   Trump would not be 'capable' of holding Ukraine-Russia peace talks, says his former national security adviser John Bolton https://t.co/2CZbuEAdRF This from an old fart Bolton. I suppose Biden would then in your opinion. Trump would not have to have a peace talk. Would be no war.
# 62   @Here78071043 @DLfermi @POTUS Russia to Ukraine: Sure, we're ready for peace talks. And we'll be happy to talk to you over your dead body.
# 63   @POTUS you should clarify the peace with Putin and not make stupid remarks, it's about peace in Europe and if there is peace and Ukraine is divided for it then so be it for peace. It's not about peace anymore. President Biden, talk to Putin, we need peace
# 64   @stonkoverlord @MrMerwara @DerekJGrossman 70% of our weapons come from russia\n\nif uk, usa gave those weapons we would gladly condemn russia openly \n\nfyi indian govt has clearly putin to talk peace with ukraine\n\nand also it was ussr who sent its aircraft carrier when usa sent its fleet to threaten us in 1971 india pak war
# 65   @With__Ukraine he needs to do more then that if that is ever going to be a thing in a peace talk xD
# 66   @JoeNBC Less talk, more action. We will remember him blocking planes, anti-missile and anti-ship weapons. I voted for him! No selling out Ukraine. No peace until Putin dead and all Russians out of all of Ukraine!
# 67   @leonidragozin If we are humane and civilised why are we at War even in our homes\nWe're worse than Animals\nWhy can't the West led by US and Russia sit together, resolve concerns that affect the 2\nNo need of makimg Ukraine a party to peace talk 'coz Ukraine is a pawn a puppet \n#RussiaUkraineWar
# 68   @_AfricanSoil Didn't zelensky declare that Ukraine was ready to talk peace with Russia?  This is so puzzling RN 🫤🫤
# 69   “The war on Ukraine is unfair and is a provoked war. But if everybody burns bridges with Russia, who will talk to them about peace?” says Ibrahim Kalin, Spokesperson and Senior Advisor to the President of the Republic of Turkey, at the #DohaForum. @ikalin1 @ChathamHouse https://t.co/zwVKeb8mhX
# 70   I finally put my finger on what is bugging me about the whole Russia Ukraine thing. You HAVE to pick a side otherwise you are pro-Putin. There is no talk of resolution. Peace. Nothing from anyone. That is really fucked up.
# 71   @zoo_bear Think!\nIf Ukraine's Zelenskyy have a direct talk withVladimir Putin , it will be held as step towards WORLD PEACE by Russian people as well as world at large.\n\nCan you say the same thing about a random Ukrainian citizen having a conversation with Russian political leadership.😅
# 72   @HollyRorie @olgatokariuk @KremlinRussia_E @Ukraine @ZelenskyyUa And you think the west are telling you the truth by blocking and censoring other news outlets with differing views? Who in his sane mind won't sit with parties to talk about peace but provide the one party with weapons? If indeed they want peace https://t.co/eHL2U2NxK4
# 73   People talk about Ukraine as if it were the only place where people are in need of help and peace
# 74   @LetsChatChiefs Why is it necessary to project the negative spin? Seriously. Change happens, players come and go. We sit here within the Twitter soapbox and make cutting remarks. It's so unnecessary. There's a war going on in Ukraine. Talk peace, not negativity.♥️🏈🌐☮🇺🇦
# 75   Today's illustration of Del Hambre in the opinion section of @el_pais  Let's talk about war.\nLike, share, support art.\n\n#illustration #artwork #StopWar #Ukraine #peace\nhttps://t.co/pIwyBJjxDW\nhttps://t.co/qJ9UnrNSl4 https://t.co/9Sc3Crgvvu
# 76   @DavidHarrisAJC @OMarkarova @tufkaa @DipAcademyUA @AJC_CE @JewishUkraine @UKRinNATO @UkrCongComAm @UKRinUN @UKRintheUSA @UKRinIsrael Don't bring Jews issues here like non live in Russia. So many communities are displaced, the Moringhas, Syrians, Libyans and others. Let Zelensky talk peace not war. Ukraine us not his personal property
# 77   @SPAtrickDempsey @RyanRZambrano What do you want us to be the WEST dog? You see what has become to ukraine? US is the reason why there is war in ukraine. I'm not saying we should not make peace all I'm saying is we should put a limit. Talk about peace and economy then move on. Watch BBM in SMNI.
# 78   @ANI In this invasion only USA is the biggest gainer as they sell weapons and oil and gas to all European countries including Ukraine. This is clear indication that they don't want to stop this war and go for peace talk. Very sad to see people of Ukraine suffer.
# 79   Ukraine nightmare\nThe immense suffering of the ppl of Ukraine demands for everyone to call for peace, peace, peace &amp; cessation of all war activities immediately. Right and wrong, villains and heroes, and all other talk is for scholars, analysts, politicians, for a later date🙏👌 https://t.co/C81UiJGnfI
# 80   From all indications #Zelensky is deluded from peace talk to I need weapons, no amount of weapons supplied to #Ukraine can defeat #Russia. 🤡 https://t.co/wbkEiNVUs4
# 81   The focus should be on ending the war and helping Ukraine to negotiate peace. Ukrainians must get their freedom, sovereignty and dignity back. They will need the world to help rebuild. Any talk of regime change in Moscow at this stage will not help in efforts to deescalate. https://t.co/rN1NPmXBCT
# 82   It's time for all wepaons of war to stop + giving more or using is a crime against Humanity! Complex life is dying at a fast rate now that sustains our food source, our read has solutions for all except a Nuclear accident! NO One should give Ukraine a weapon, please make peace!
# 83   @serjtankian I think if russia bombs Yerevan tomorrow,  Serj will still say US is doing nothing,  and russia is "calling for peace "\n\nWhen russia has totally ruined few big cities in Ukraine, Serj is enough enjoying russian dick to talk about them as a "peacemaker". wow..
# 84   Trump Wouldn't Be 'Capable' Of Ukraine Peace Talks With Moscow, Says John Bolton https://t.co/sRW6XIpTVI via @Yahoo Agree Bolton,this traitor will give awayUS in peace talk with Putin.Can not believe he said"US intelligence is pretty bad"in front of the World in Helsinki meeting.
# 85   @NatashaBertrand The reason why Biden does not want to directly talk to Putin, instead just constantly fueling the fire is - Biden does not need Ukraine to return to peace too soon as this will jeopardize the US strategy in containing/weakening Russia.
# 86   @Reuters Do the same in your country stop the war and talk and let the world live in peace every 4 to 8 years Mr Putin starts a new chechnya Georgia Syria crimea Ukraine
# 87   @CedricAaron5 @SterKekerel @leclussy @POTUS Chinese people are always smart 🤍🤍🤍 Americans are clowns. They are talking about ukraine and talking about peace, human rights. While the inavde Hundreds of poor countries and killing people that are in it. They never should talk about peace and justice never
# 88   The US’d new foreign policy approach is posting photos of @POTUS eating pizza with troops. No talk of peace. Ukraine cannot defeat Russia and neither can US/@NATO. Negotiate for peace. https://t.co/pWupEymlwn
# 89   @ForeignAffairs @rajan_menon_ Isn't Ukraine winning? \n\nAccording to western media.\n\nI thought we were closing in on Moscow, Putin is about to be captured.\n\nAnd Lviv bombing isn't a desperation move?\n\nNo peace talk while victory is near.
# 90   @Kasparov63  I get really pissed off when people talk about Ukraine and say Maybe they should give up Crimea and Donbas in exchange for peace.\nWhy the fuck should they?\nThis is their country, all of it and it does not belong to russia or it's friends.\n#SlavaUkraini  #StopRussia
# 91   Oil drops on China demand worries, Ukraine peace talk hopes https://t.co/TvwP1Majur via FXEmpire #forex #fx
# 92   Oil drops on China demand worries, Ukraine peace talk hopes https://t.co/NRsSlEemdJ
# 93   @NeilPHauer I get really pissed off when people talk about Ukraine and say Maybe they should give up Crimea and Donbas in exchange for peace.\nWhy the fuck should they?\nThis is their country, all of it and it does not belong to russia or it's friends.\n#SlavaUkraini  #StopRussia
# 94   @barefootboomer I get really pissed off when people talk about Ukraine and say Maybe they should give up Crimea and Donbas in exchange for peace.\nWhy the fuck should they?\nThis is their country, all of it and it does not belong to russia or it's friends.\n#SlavaUkraini  #StopRussia
# 95   @IAPonomarenko I get really pissed off when people talk about Ukraine and say Maybe they should give up Crimea and Donbas in exchange for peace.\nWhy the fuck should they?\nThis is their country, all of it and it does not belong to russia or it's friends.\n#SlavaUkraini  #StopRussia
# 96   @Osinttechnical I get really pissed off when people talk about Ukraine and say Maybe they should give up Crimea and Donbas in exchange for peace.\nWhy the fuck should they?\nThis is their country, all of it and it does not belong to russia or it's friends.\n#SlavaUkraini  #StopRussia
# 97   I get really pissed off when people talk about Ukraine and say Maybe they should give up Crimea and Donbas in exchange for peace.\nWhy the fuck should they?\nThis is their country, all of it and it does not belong to russia or it's friends.\n#SlavaUkraini  #StopRussia
# 98   Oil drops on China demand worries, Ukraine peace talk hopes#ukrainewar   | ⚠️  LiveTube is looking for people in #Ukraine who can start a live stream from their mobile. DM us. \nhttps://t.co/giXNUrKnFf
# 99   @Johnny_Joey If Amer is involved in the peace talk we will throw Ukraine to the wolves like we did the Afghan people. Zelensky should not trust Amer on anything they are involved in
# 100  @KennedyNation If Amer is involved in the peace talk we will throw Ukraine to the wolves like we did the Afghan people. Zelensky should not trust Amer on anything they are involved in
# 101  "Oil drops on China demand worries, Ukraine peace talk hopes"\n\nhttps://t.co/E4Hj2ttwXl
# 102  Putin is still murdering Ukrainians, so, we can assume he doesn't want to talk about peace. https://t.co/EZtLkitXZg #Ukraine  #RussiaUkraineCrisis #UkraineWar #UkraineUnderAttack #Russia #RussianArmy #Biden #GOPTraitors #Zelenskyy
# ...
# 102  VintageAmerica8  2
# 103  newsinvesting    1
# 104  ChannelNewsAsia  2
# 105  ChangPants       0
# 106  StckPro          0
# 107  Barbistall       2
# 108  Okey_biggy       0
# 109  Roseangel009     12
# 110  coreylosco       1
# 111  ShihtzuLove08    0
# 112  woye1            165
# 113  Geminigal57      0
# 114  ugone2us475      0
# 115  temmywunmi009    0
# 116  _BigDzu          1
# 117  LeftHandStu      0
# 118  NunyaIm          4
# 119  DAngeledes       1
# 120  lettera_marco    0
# 121  NwabuwaChidume   0
# 122  BostonScribe1    0
# 123  LokalKontent     0
# 124  massoudkhwaja    0
# 125  zeketweetss      0
# 126  AlhajiMetomi     3
# 127  DEFENSEEXPRESS   4
# 128  FI55928140       2
# 129  Dwain415         0
# 130  mysticability    0
# 131  DeanObeidallah   20
# 132  Bimbolafredrick  1
# 133  dallasme110      0
# 134  Bimbolafredrick  4
# 135  lordweb1         0
# 136  pbtips_          193
# 137  martinbott75334  0
# 138  AnarchoCorvidae  26
# 139  tejjena          0
# 140  Eactivist_sa     1
# 141  joaonsalvador    0
# 142  MarketRebels     85
# 143  rayveysey        0
# 144  nativ_truth      0
# 145  TarasDemerson    3
# 146  Michael_Z1012    0
# 147  Rawle95Rawle951  1
# 148  majorprivate080  0
# 149  misspetitenaija  0
# 150  apkaapnanews     0
# 151  CliqNigeria      1
# 152  rosemary_kerr14  1
# 153  StianHanssen26   0
# 154  Tesfale64947806  4
# 155  DrBricker1968    0
# 156  dipak_chelsea    2
# 157  Sportsinformer3  0
# 158  sendinben        7
# 159  echonewsng1      1
# 160  VoigemastVirgo   0
# 161  doryowen         5
# 162  jakebebber       120
# 163  PulseNets1       0
# 164  Milda94941403    0
# 165  progressero      0
# 166  Equateall        3
# 167  niyitabiti       1
# 168  splippincott     1
# 169  somtosports      0
# 170  nsmupdate        1
# 171  nairaland        1
# 172  el_bruise        1
# 173  kktotlani        8
# 174  newmind99        3
# 175  960weli          0
# 176  TheBlueApe       2
# 177  iam_ramires      1
# 178  Johnjohn1347     1
# 179  waifai           0
# 180  mirzahyd1        0
# 181  WorldPeace33334  1
# 182  TheGuildng       0
# 183  WarInUkraineYet  1
# 184  schellhor        0
# 185  solusnan1        0
# 186  jsmclaughlin     9
# 187  iSaviT1149       0
# 188  MadelynSmadi     1
# 189  WGlassy          0
# 190  Bitfargo         3
#
#                                            Display Name Language
# 0    Mona Salama                                         en
# 1    Berhan                                              en
# 2    Ola Coola                                           en
# 3    P-DR                                                en
# 4    Terryska Walliski 🇪🇺 #IStandWithJeremyCorbyn        en
# 5    A Good Concious                                     en
# 6    Peace Love                                          en
# 7    Peace Love                                          en
# 8    Nsemgh                                              en
# 9    Albert Bergonzo                                     en
# 10   Devashish Ganguly                                   en
# 11   Dr. Mohammed Zaman                                  en
# 12   Those who died and are doing well 🇬🇧🇳🇬              en
# 13   Dory Owen                                           en
# 14   K o b i ☮️                                          en
# 15   Shadow 🇺🇦                                           en
# 16   gabriela rata                                       en
# 17   John 3:16                                           en
# 18   Peace Love Rock N Roll                              en
# 19   Superhuman                                          en
# 20   gabriela rata                                       en
# 21   Gibson Njeri                                        en
# 22   Peter Aleksiun                                      en
# 23   Ronald James                                        en
# 24   jarek2                                              en
# 25   Jen                                                 en
# 26   D.Y                                                 en
# 27   RJ                                                  en
# 28   Satyrnalia                                          en
# 29   avalonlaundry                                       en
# 30   Brian Brandt                                        en
# 31   Talk is Cheap                                       en
# 32   Khalid Mehmood                                      en
# 33   Maxwell                                             en
# 34   Małgorzata                                          en
# 35   Mingawinki 🕊🇺🇦 give peace a chance 🇺🇦🕊              en
# 36   skingers                                            en
# 37   rhepodcast                                          en
# 38   Sabine fanm                                         en
# 39   John Hutchison                                      en
# 40   syadoz                                              en
# 41   William Melvin                                      en
# 42   Between The Lines                                   en
# 43   Business News                                       en
# 44   Jorge🇨🇱🇾🇪🇺🇦                                         en
# 45   V                                                   en
# 46   Nick Stallard 🇬🇧🇺🇦                                  en
# 47   BenO                                                en
# 48   The Mighty Zing                                     en
# 49   Yaroslav                                            en
# 50   Iampraveen                                          en
# 51   Michael O'Neill Vaxxed Bot                          en
# 52   Satch Guba                                          en
# 53   Peaceful Warrior ☮️🥷🇺🇸🇰🇷🇺🇦                          en
# 54   🇺🇦 PETRO THE UKRANIAN 🇺🇦                            en
# 55   jorgeviola                                          en
# 56   Proud to be Canadian                                en
# 57   𝑫𝒂𝒏𝒊 🇦🇷                                             en
# 58   John                                                en
# 59   MacktheKnife                                        en
# 60   Septembre                                           en
# 61   Linda M Villwock                                    en
# 62   Robin Messing                                       en
# 63   Alfred🇷🇺🇩🇪                                          en
# 64   ☀️                                                  en
# 65   MadAtTheGalaxy                                      en
# 66   md                                                  en
# 67   mahen                                               en
# 68   GENERATIONAL CURSE BREAKER 📍                        en
# 69   Doha Forum                                          en
# 70   HermienV                                            en
# 71   Amiya Kashyap                                       en
# 72   xcalibar                                            en
# 73   jules                                               en
# 74   G Callahan☯️                                        en
# 75   Raro_                                               en
# 76   Govunor Edyau                                       en
# 77   Ilobmoni                                            en
# 78   Siva Shankar                                        en
# 79   Dr. P@Indiamusings, PhD                             en
# 80   Pacifist 🐉                                          en
# 81   Narendra Taneja                                     en
# 82   kara j lincoln, `i come to talk story...            en
# 83   Михайло                                             en
# 84   subrata                                             en
# 85   Jacky Cheung                                        en
# 86   Sudeep Patel 🇮🇳                                     en
# 87   Fearless                                            en
# 88   Gerald Celente                                      en
# 89   bobotom2019                                         en
# 90   Michael Marshall                                    en
# 91   BlackCentaurFX                                      en
# 92   Cengiz Adabag                                       en
# 93   Michael Marshall                                    en
# 94   Michael Marshall                                    en
# 95   Michael Marshall                                    en
# 96   Michael Marshall                                    en
# 97   Michael Marshall                                    en
# 98   LiveTube                                            en
# 99   klsparrow                                           en
# 100  klsparrow                                           en
# 101  Pope 🍪 🧒 the 1st ®                                  en
# 102  VintageAmerican                                     en
# 103  Investing.com News                                  en
# 104  CNA                                                 en
# 105  Michael Chang                                       en
# 106  STCK.PRO                                            en
# 107  Barbara May                                         en
# 108  Okey Okeke                                          en
# 109  Red Rose🌹Chelsea First Lady💙                        en
# 110  HanzoTheRazor                                       en
# 111  DetroitvsEverybody                                  en
# 112  Woye                                                en
# 113  UKfriend                                            en
# 114  Blueberry                                           en
# 115  Adewunmi Wunmi                                      en
# 116  🐬👑🏁                                                 en
# 117  Stuart                                              en
# 118  IM Nunya 🌻🌻🌻#СлаваУкраїні 🌻🌻🌻                       en
# 119  incognito                                           en
# 120  Marco Lettera                                       en
# 121  Chidume                                             en
# 122  thebostonscribe                                     en
# 123  Lokal Kontent                                       en
# 124  Massoud                                             en
# 125  Zeke                                                en
# 126  Oluwametomifunmi                                    en
# 127  DEFENSE EXPRESS                                     en
# 128  F.I                                                 en
# 129  Dwain                                               en
# 130  American Boy Of LAGOS💦                              en
# 131  (((DeanObeidallah)))                                en
# 132  The Mechanic guy                                    en
# 133  KG                                                  en
# 134  The Mechanic guy                                    en
# 135  lord web                                            en
# 136  PROFESSIONAL BETS 🏀⚽️                               en
# 137  wwwtotalitaerde                                     en
# 138  Crowpotkin 🏴                                        en
# 139  Tejjena Daniel                                      en
# 140  Extreme Activist                                    en
# 141  JNSalvador                                          en
# 142  Market Rebellion                                    en
# 143  Ray Veysey                                          en
# 144  ADA FAM - STOP GIVING AWAY OUR GOOD NAME FOR FREE.  en
# 145  Fior di Battaglia 💪🇺🇦 ще не вмерла Україна          en
# 146  🇺🇸America&United🇺🇲                                  en
# 147  Rawle95                                             en
# 148  Monstro                                             en
# 149  Miss Petite Nigeria                                 en
# 150  Entertainment Chacha                                en
# 151  Cliq Nigeria.                                       en
# 152  Rosemary_Kerr14                                     en
# 153  Stian Hanssen                                       en
# 154  Tesfalem                                            en
# 155  The Rev. Horta Heat                                 en
# 156  Dipak Jangpangi                                     en
# 157  Sports Informer                                     en
# 158  Ben Burris                                          en
# 159  echonewsng                                          en
# 160  Võigemast Virgo                                     en
# 161  Dory Owen                                           en
# 162  NavyCane                                            en
# 163  PulseNets                                           en
# 164  Milda 🇱🇹🌻🇺🇦                                         en
# 165  Progressive                                         en
# 166  EquateAll                                           en
# 167  niyi tabiti                                         en
# 168  Sean Lippincott                                     en
# 169  Somtosport                                          en
# 170  Nsmnews Nigerian forum page                         en
# 171  Nairaland Forum                                     en
# 172  Dr el-bruise                                        en
# 173  I AM Modi Totlani Krishan🇮🇳                         en
# 174  StClair ⚡ NordicAsset                               en
# 175  News/Talk 960 WELI                                  en
# 176  Freedom & Whisky 🇮🇪🇺🇸🥃                              en
# 177  I 🗣️⚽On📺&📻                                          en
# 178  Johnjohn134                                         en
# 179  frank                                               en
# 180  Mirza Hyderabad.                  (میرزا حیدرآباد)  en
# 181  JEANNIE                                             en
# 182  The Guild Nigeria                                   en
# 183  There is War in Ukraine                             en
# 184  Carolin Schellhorn                                  en
# 185  𝓝𝓐𝓝𝓒𝓔 🦋🌊🦋                                           en
# 186  John McLaughlin                                     en
# 187  iSaviSmile                                          en
# 188  Smadi Madelyn                                       en
# 189  GlassyW                                             en
# 190  Bitfargo                                            en

# %% [markdown]
# ### Getting user data
#
# This is done with tweepy. To make this work you will need to sign up for a twitter developers account and put your keys into a key config file. User data which we will want includes:
# - Number of followers
# - Number following (called friends in the API)
# - Potentially the names of follows
# - Potentially the number following
# - Potentially the location
# Whilst it would be great to get the names of at least some of a users followers and friends, getting them is severely limited by tweepys limit of 15 friends/followers requests of a user every 15 minutes. We can however get the number of friends/followers which has a much higher rate limit, supposedly around 300 requests every 15 minutes but it actually appears to be higher in practice, somewhere around 900/10 mins but this fluctuates.

# %%
import json
import tweepy

# Load my API keys
with open("../twitter_keys_config.json") as cfg_file:
    config = json.load(cfg_file)
    
# Setup tweepy API
consumer_key = config["API_key"]
consumer_secret = config["API_secret"]
access_token = config["access_token"]
access_token_secret = config["access_secret"]

# authorization of consumer key and consumer secret
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# set access to user's access key and access secret
auth.set_access_token(access_token, access_token_secret)

# calling the api
api = tweepy.API(auth, wait_on_rate_limit = True)

# %%
# Get number of followers function
def get_num_followers_and_friends(username):
    user = api.get_user(screen_name = username)
    followers_count = user.followers_count
    friends_count = user.friends_count
    
    return followers_count, friends_count

# Iterrate through a dataframe and add columns for num friends and num followers
def add_num_followers_and_friends(tweets_df): 
    for idx, tweet in tqdm(tweets_df.iterrows()):
        username = tweet['Username']

        try:
            num_followers, num_friends = get_num_followers_and_friends(username)

        # Exception for if tweepy cuts you off for too many requests
        # EVEN though wait_on_rate_limit = True should address this!!
        except tweepy.errors.TweepyException:
            wait_time = 60
            print("Tweepy rate limit reached and native tweepy solution failed, waiting", wait_time, "s")
            time.sleep(wait_time)
            
        # Exception for if an account has been deleted since scraping tweets
        except tweepy.errors.NotFound:
            print("Username", username, "not found, skipping")
            num_followers, num_friends = 0,0 # TODO Make this zero or some error value?
            
        
        tweets_df.loc[idx, 'Num Followers'] = num_followers
        tweets_df.loc[idx, 'Num Friends'] = num_friends
    
    return tweets_df

tweets_en_df = add_num_followers_and_friends(tweets_en_df)
tweets_ru_df = add_num_followers_and_friends(tweets_ru_df)
tweets_uk_df = add_num_followers_and_friends(tweets_uk_df)
# Out:
# 900it [06:07,  2.94it/s]Rate limit reached. Sleeping for: 533
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 1801it [21:53,  2.86it/s]Rate limit reached. Sleeping for: 548
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 2702it [37:31,  2.81it/s] Rate limit reached. Sleeping for: 571
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 3603it [53:37,  2.85it/s] Rate limit reached. Sleeping for: 567
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 4504it [1:09:18,  3.06it/s] Rate limit reached. Sleeping for: 587
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 5405it [1:25:38,  2.80it/s] Rate limit reached. Sleeping for: 569
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 6306it [1:42:14,  2.91it/s] Rate limit reached. Sleeping for: 572
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 7207it [1:58:11,  3.06it/s] Rate limit reached. Sleeping for: 577
# 8107it [2:13:24,  2.89it/s] Rate limit reached. Sleeping for: 566
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 9008it [2:29:13,  2.77it/s] Rate limit reached. Sleeping for: 578
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 9909it [2:45:40,  3.03it/s] Rate limit reached. Sleeping for: 553
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 10272it [2:58:13,  2.85it/s]
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 10810it [3:02:39,  2.98it/s]Rate limit reached. Sleeping for: 496
# 11710it [3:16:06,  2.76it/s] Rate limit reached. Sleeping for: 589
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 12530it [3:32:02,  2.89it/s]
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 12611it [3:33:45,  2.31it/s]Rate limit reached. Sleeping for: 491
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 13512it [3:48:48,  1.94it/s] Rate limit reached. Sleeping for: 549
# 14392it [4:03:25,  2.68it/s]
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 14412it [4:04:32,  2.76it/s]Rate limit reached. Sleeping for: 506
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 15313it [4:19:04,  3.04it/s] Rate limit reached. Sleeping for: 596
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 16214it [4:35:13,  2.14it/s] Rate limit reached. Sleeping for: 588
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 17115it [4:51:33,  3.06it/s] Rate limit reached. Sleeping for: 570
# 18015it [5:07:39,  2.79it/s] Rate limit reached. Sleeping for: 506
# 18084it [5:16:30,  2.97it/s]
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 18915it [5:22:19,  3.08it/s]Rate limit reached. Sleeping for: 527
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 18976it [5:32:29,  2.25it/s]
# Tweepy rate limit reached and native tweepy solution failed, waiting 60 s
# 19105it [5:34:13,  1.05s/it]
# 79it [00:26,  2.94it/s]
# 8it [00:02,  2.91it/s]

# %%
dir(tweepy.errors)
# Out:
# ['BadRequest',
#  'Forbidden',
#  'HTTPException',
#  'NotFound',
#  'TooManyRequests',
#  'TweepyException',
#  'TwitterServerError',
#  'Unauthorized',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'requests']

# %% [markdown]
# ### Save dataframes

# %%
tweets_en_df.to_csv('data/tweets_raw_en_df_' + keywords_en.replace(' ', '_') + str(num_tweets) + 'dailytweets_' + start_date + '_to_' + end_date + '.csv')
tweets_ru_df.to_csv('data/tweets_raw_ru_df_' + keywords_ru.replace(' ', '_') + str(num_tweets) + 'dailytweets_' + start_date + '_to_' + end_date + '.csv')
tweets_uk_df.to_csv('data/tweets_raw_uk_df_' + keywords_uk.replace(' ', '_') + str(num_tweets) + 'dailytweets_' + start_date + '_to_' + end_date + '.csv')

# %%
keywords_en.replace(' ', '_')
# Out:
# 'mcdonalds_russia'
