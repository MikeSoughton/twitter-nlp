# %%
#!pip install git+https://github.com/JustAnotherArchivist/snscrape.git
import snscrape.modules.twitter as sntwitter
import pandas as pd

# A test
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-v0gnb62i
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-v0gnb62i
# ...
# ERROR: Package 'snscrape' requires a different Python: 3.7.12 not in '~=3.8'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e1dd03d1498c> in <module>()
#       1 get_ipython().system('pip install git+https://github.com/JustAnotherArchivist/snscrape.git')
# ----> 2 import snscrape.modules.twitter as sntwitter
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'snscrape'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# ...

# %%
# !python --version
# Out:
# Python 3.10.0

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-28').get_items()):
    print(i)
    if i>1000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])
# Out:
# 0
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/hx/0dxb0wn51wx5pscstjkwf2gc000qqf/T/ipykernel_20876/3484702245.py in <module>
#       3
#       4 # Using TwitterSearchScraper to scrape data and append tweets to list
# ----> 5 for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-28').get_items()):
#       6     print(i)
#       7     if i>1000:
#
# ~/opt/anaconda3/envs/twitter-covid-test/lib/python3.10/site-packages/snscrape/modules/twitter.py in get_items(self)
#     802
#     803                 for obj in self._iter_api_data('https://api.twitter.com/2/search/adaptive.json', _TwitterAPIType.V2, params, paginationParams, cursor = self._cursor):
# --> 804                         yield from self._v2_timeline_instructions_to_tweets(obj)
#     805
#     806         @classmethod
#
# ...

# %%
tweets_df2.to_csv('First Extract.csv')

# %%
tweets_df2
# Out:
#                       Datetime             Tweet Id  \
# 0    2021-02-27 23:59:59+00:00  1365813964756692993
# 1    2021-02-27 23:59:59+00:00  1365813964320501767
# 2    2021-02-27 23:59:58+00:00  1365813962739179523
# 3    2021-02-27 23:59:58+00:00  1365813959333318656
# 4    2021-02-27 23:59:57+00:00  1365813958163111938
# ...                        ...                  ...
# 996  2021-02-27 23:37:53+00:00  1365808403113730048
# 997  2021-02-27 23:37:51+00:00  1365808396348362755
# 998  2021-02-27 23:37:50+00:00  1365808391990435852
# 999  2021-02-27 23:37:49+00:00  1365808388031078403
# 1000 2021-02-27 23:37:49+00:00  1365808384637865986
#
#                                                    Text         Username  \
# 0     Are you ready to roll your sleeve up for the C...           USAGov
# 1     I've been trying to tweet about Dr Yeadon, for...        seeker375
# 2     U.S. authorizes Johnson &amp; Johnson’s COVID-...  The_StreetPress
# ...

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-24').get_items()):
    if i>1000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df3 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df3.to_csv('Second Extract.csv')

# %%
tweets_df3
# Out:
#                       Datetime             Tweet Id  \
# 0    2021-02-23 23:59:59+00:00  1364364414372093962
# 1    2021-02-23 23:59:49+00:00  1364364372441587718
# 2    2021-02-23 23:59:43+00:00  1364364345426206722
# 3    2021-02-23 23:59:41+00:00  1364364338753110019
# 4    2021-02-23 23:59:31+00:00  1364364294050078720
# ...                        ...                  ...
# 996  2021-02-23 23:15:08+00:00  1364353125642076164
# 997  2021-02-23 23:15:08+00:00  1364353125281325057
# 998  2021-02-23 23:15:08+00:00  1364353125088452608
# 999  2021-02-23 23:15:08+00:00  1364353124945846280
# 1000 2021-02-23 23:15:08+00:00  1364353124648046599
#
#                                                    Text         Username  \
# 0     Pasado na sa Senado ang Vaccine Program Bill! ...      SenGracePOE
# 1     @GovTimWalz Shame on you for claiming to care ...        Cooly9759
# 2     golden by harry styles was playing while I got...  dxzzyoncaffeine
# ...

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-20').get_items()):
    if i>1000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df4 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df4.to_csv('Third Extract.csv')

# %%
tweets_df4
# Out:
#                       Datetime             Tweet Id  \
# 0    2021-02-19 23:59:58+00:00  1362914858409205761
# 1    2021-02-19 23:59:56+00:00  1362914848737140739
# 2    2021-02-19 23:59:55+00:00  1362914846937817090
# 3    2021-02-19 23:59:44+00:00  1362914799328366596
# 4    2021-02-19 23:59:43+00:00  1362914794848858115
# ...                        ...                  ...
# 996  2021-02-19 23:09:52+00:00  1362902248985137153
# 997  2021-02-19 23:09:46+00:00  1362902223844352000
# 998  2021-02-19 23:09:45+00:00  1362902220178481154
# 999  2021-02-19 23:09:44+00:00  1362902215749419010
# 1000 2021-02-19 23:09:42+00:00  1362902208875016192
#
#                                                    Text         Username  \
# 0     @KSL5TV If the @US_FDA doesn’t approve this em...        jewels_my
# 1     .@ABC's broadcast: LIVE: Our @ABC News team ha...  AmericaDialogue
# 2     Thoughts on the covid vaccines leading to anti...    PinkneyJodian
# ...

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-17').get_items()):
    if i>1000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df5 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df5.to_csv('Fourth Extract.csv')

# %%
tweets_df5
# Out:
#                       Datetime             Tweet Id  \
# 0    2021-02-16 23:59:59+00:00  1361827698272706566
# 1    2021-02-16 23:59:56+00:00  1361827686805475328
# 2    2021-02-16 23:59:56+00:00  1361827685341663232
# 3    2021-02-16 23:59:54+00:00  1361827679125663747
# 4    2021-02-16 23:59:47+00:00  1361827647085510659
# ...                        ...                  ...
# 996  2021-02-16 23:07:29+00:00  1361814487490174977
# 997  2021-02-16 23:07:29+00:00  1361814484793221123
# 998  2021-02-16 23:07:13+00:00  1361814418766651396
# 999  2021-02-16 23:07:11+00:00  1361814410155720706
# 1000 2021-02-16 23:07:03+00:00  1361814378002018304
#
#                                                    Text         Username  \
# 0     While they focused on bathroom bills, “show me...      BetoORourke
# 1     @pajhwok @AFP This is good for WHO to give Afg...  Estrell45533352
# 2     question: have you received a COVID vaccine ye...       avaryanne_
# ...

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-13').get_items()):
    if i>1000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df6 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df6.to_csv('Fifth Extract.csv')

# %%
tweets_df6
# Out:
#                       Datetime             Tweet Id  \
# 0    2021-02-12 23:59:53+00:00  1360378122328281089
# 1    2021-02-12 23:59:52+00:00  1360378117731221504
# 2    2021-02-12 23:59:52+00:00  1360378117546770434
# 3    2021-02-12 23:59:51+00:00  1360378113704611841
# 4    2021-02-12 23:59:49+00:00  1360378104506699781
# ...                        ...                  ...
# 996  2021-02-12 23:07:09+00:00  1360364851063783424
# 997  2021-02-12 23:07:05+00:00  1360364832952901634
# 998  2021-02-12 23:07:03+00:00  1360364824979472393
# 999  2021-02-12 23:07:03+00:00  1360364824966828033
# 1000 2021-02-12 23:07:02+00:00  1360364822198513666
#
#                                                    Text       Username  \
# 0     Words i now detest....\nBubble, isolate, restr...      obmarch05
# 1     While COVID-19 vaccines help build immunity fo...        LCl2021
# 2     Swedish university wants to test-compare Covid...       LouSedin
# ...

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-10').get_items()):
    if i>1000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df7 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df7.to_csv('Sixth Extract.csv')

# %%
tweets_df7
# Out:
#                       Datetime             Tweet Id  \
# 0    2021-02-09 23:59:51+00:00  1359290949118091268
# 1    2021-02-09 23:59:46+00:00  1359290928540827648
# 2    2021-02-09 23:59:42+00:00  1359290910455037956
# 3    2021-02-09 23:59:41+00:00  1359290909498703878
# 4    2021-02-09 23:59:31+00:00  1359290866247102467
# ...                        ...                  ...
# 996  2021-02-09 23:12:50+00:00  1359279119112962048
# 997  2021-02-09 23:12:42+00:00  1359279084170334211
# 998  2021-02-09 23:12:41+00:00  1359279079464132622
# 999  2021-02-09 23:12:39+00:00  1359279072979918853
# 1000 2021-02-09 23:12:36+00:00  1359279057527996416
#
#                                                    Text       Username  \
# 0     J&amp;J's single-dose Covid vaccine is being h...           CNBC
# 1     UPDATE ON STOLEN COVID 19 DOSES | 🧵| We have a...  RosalesReport
# 2     How chronic underfunding fueled Georgia’s Covi...       storbush
# ...

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-06').get_items()):
    if i>1000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df8 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df8.to_csv('Seventh Extract.csv')

# %%
tweets_df8
# Out:
#                       Datetime             Tweet Id  \
# 0    2021-02-05 23:59:55+00:00  1357841415347273729
# 1    2021-02-05 23:59:51+00:00  1357841398645547010
# 2    2021-02-05 23:59:50+00:00  1357841393973157894
# 3    2021-02-05 23:59:37+00:00  1357841340571213827
# 4    2021-02-05 23:59:35+00:00  1357841332543365121
# ...                        ...                  ...
# 996  2021-02-05 23:15:08+00:00  1357830144036061187
# 997  2021-02-05 23:15:05+00:00  1357830132166189059
# 998  2021-02-05 23:15:03+00:00  1357830125019037696
# 999  2021-02-05 23:15:02+00:00  1357830119008600066
# 1000 2021-02-05 23:15:01+00:00  1357830117033189379
#
#                                                    Text       Username  \
# 0     The 3 links mentioned this hour on @catholicco...    FrMatthewLC
# 1     THIS SUNDAY: Days before the Senate impeachmen...   MeetThePress
# 2     At 8 a.m. on Feb. 8, we'll launch a #COVID19 V...    mynorthoaks
# ...

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-03').get_items()):
    if i>1000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df9 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df9.to_csv('Eighth Extract.csv')

# %%
tweets_df9
# Out:
#                       Datetime             Tweet Id  \
# 0    2021-02-02 23:59:58+00:00  1356754262525571074
# 1    2021-02-02 23:59:57+00:00  1356754258096455687
# 2    2021-02-02 23:59:56+00:00  1356754256531845122
# 3    2021-02-02 23:59:54+00:00  1356754248046759936
# 4    2021-02-02 23:59:53+00:00  1356754241247989764
# ...                        ...                  ...
# 996  2021-02-02 23:20:34+00:00  1356744350391296005
# 997  2021-02-02 23:20:33+00:00  1356744344884023297
# 998  2021-02-02 23:20:33+00:00  1356744342602305537
# 999  2021-02-02 23:20:33+00:00  1356744342560403456
# 1000 2021-02-02 23:20:31+00:00  1356744334612324354
#
#                                                    Text        Username  \
# 0     @TheTorontoSun Because it's Calgary and not Mo...     CRC57325971
# 1     I do have an issue with all the news stories a...          wgkcss
# 2     A survey spearheaded by UST researchers shows ...  cnnphilippines
# ...

# %%
Tweets_Feb = pd.concat([tweets_df2,tweets_df3,tweets_df4,tweets_df5,tweets_df6,tweets_df7,tweets_df8,tweets_df9])

# %%
Tweets_Feb.shape
# Out:
# (8008, 7)

# %%
Tweets_Feb.to_csv('Tweets_Feb.csv')
